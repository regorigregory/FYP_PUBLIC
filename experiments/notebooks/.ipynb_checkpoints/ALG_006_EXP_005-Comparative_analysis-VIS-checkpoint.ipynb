# %% [markdown]
# <h1 id="Comparative-analysis-on-the-implemented-bilateral-filtering-technique">Comparative analysis on the implemented bilateral filtering technique</h1>
# (Soon to be updated...No discussion on truncation values...)
# <h2 id="Introduction">Introduction</h2>
# <p>A more than incremental step upwards from constant weight (CW) approaches are adaptive weight approaches. In this notebook one of them, bilateral support weight windows were implemented to this pipeline.</p>
# <h2 id="Abstract">Abstract</h2>
# <p>Two variants of bilateral weights were &nbsp;introduced to the pipeline as part of the cost function. These were referred to as &ldquo;summed&rdquo; and &ldquo;product weight&rdquo; variants. As their name suggests, the summed entailed the summation of the intensity and spatial weights whereas the &ldquo;product&rdquo; expression entailed the multiplication of the aforementioned two components of bilateral weights. The achieved improvement with respect to the previous iteration, where CW windows were used, was 17%. Achieved percentage of bad pixels (with threshold of 1 &ndash; bad4 here) was 29.4 % which approximates the performance of the pipeline to be at around the 41<sup>st</sup> &nbsp;place in the Middlebury Stereo Evaluation Framework&rsquo;s (version 3) chart. Horizontal structural noise and a large number of streaking artefacts were observed upon visual analysis.</p>
# <h2 id="Relevant-theory">Relevant theory</h2>
# <p>have been&nbsp; countless techniques proposed for cost aggregation in the stereo matching pipeline in order to improve on matching accuracy. Perhaps the first and simplest is what Fang termed as Constant Window Aggregation (Fang <em>et al.</em>, 2012). This entails the aggregation of cost within a window (a matrix of adjacent pixels around a pixel that is &nbsp;subject to cost). This, using Fang&rsquo;s notation, can be generalised as</p>
# <p>&nbsp;</p>
# <table width="100%">
# <tbody>
# <tr>
# <td width="7%">&nbsp;</td>
# <td width="86%"><span class="MathJax_Preview" style="color: inherit;"><span id="MJXp-Span-314" class="MJXp-math MJXp-display"><span id="MJXp-Span-315" class="MJXp-msubsup"><span id="MJXp-Span-316" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">C</span><span id="MJXp-Span-317" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-318" class="MJXp-mtext">CW</span></span></span><span id="MJXp-Span-319" class="MJXp-mrow"><span id="MJXp-Span-320" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">(</span><span id="MJXp-Span-321" class="MJXp-mi MJXp-italic">x</span><span id="MJXp-Span-322" class="MJXp-mo" style="margin-left: 0em; margin-right: 0.222em;">,</span><span id="MJXp-Span-323" class="MJXp-mi MJXp-italic">y</span><span id="MJXp-Span-324" class="MJXp-mo" style="margin-left: 0em; margin-right: 0.222em;">,</span><span id="MJXp-Span-325" class="MJXp-mi MJXp-italic">d</span><span id="MJXp-Span-326" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">)</span></span><span id="MJXp-Span-327" class="MJXp-mo" style="margin-left: 0.333em; margin-right: 0.333em;">=</span><span id="MJXp-Span-328" class="MJXp-munderover"><span class="MJXp-over"><span id="MJXp-Span-357" class="MJXp-mrow" style="margin-right: 0px; margin-left: 0px;"></span><span class=""><span id="MJXp-Span-329" class="MJXp-mo" style="margin-left: 0.111em; margin-right: 0.167em;"><span class="MJXp-largeop">&sum;</span></span></span></span><span class=" MJXp-script"><span id="MJXp-Span-330" class="MJXp-mrow" style="margin-left: 0px;"><span id="MJXp-Span-331" class="MJXp-mi">&forall;</span><span id="MJXp-Span-332" class="MJXp-mrow"><span id="MJXp-Span-333" class="MJXp-mo" style="vertical-align: -0.387em;"><span class="MJXp-right MJXp-scale5" style="font-size: 2.547em; margin-left: -0.13em;">(</span></span><span id="MJXp-Span-334" class="MJXp-msubsup"><span id="MJXp-Span-335" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;
class="MJXp-mo" style="margin-left: 0em; margin-right: 0em; vertical-align: -0.387em;"><span class="MJXp-right MJXp-scale5" style="font-size: 2.547em; margin-left: -0.13em;">),</span></span></span></span></span></span></td>
# <td width="7%">
# <p>(1)</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>where <em>𝒩</em>(<em>𝑥</em><em>, </em><em>𝑦</em>) is a set of pixels (represented by their x and y coordinates) within a support window around a pixel (P(x,y))&nbsp; each one of them having constant weight, a constant say in the outcome. This approach was employed as part of this project&rsquo;s experiment &ldquo;ALG_005_EXP_001-PatchMatch-MacLean_et_al-Numba&rdquo; resulting in a 6-9% accuracy improvement compared to the results reported by Madeo et al. (2016) with regards to the scenes Teddy and Cones of the Middlebury 2003 dataset. A more challenging dataset, Middlebury 2014 was tested as well (<a href="ALG_005_EXP_003-PatchMatch_2014-VIS.ipynb" target="_blank" rel="noopener">ALG_005_EXP_003-PatchMatch_2014-VIS</a>) achieving an overall 49.67% bad pixel ratio (with the threshold of 1 pixel difference). While this number may seem high, this performance would place the algorithm at the 88<sup>th</sup> position in the Middlebury Stereo Evaluation Framework&rsquo;s chart (Scharstein and Hirschm&uuml;ller, 2014).&nbsp;</p>
# <p>According to Fang, after CW, the proposed solutions branched into two categories: Cross-Based Aggregation (CROSS) and Adaptive Weight Aggregation (AW). While both ideas seemed interesting to consider for implementation, later work (Hamzah and Ibrahim, 2016)&nbsp; suggested that Adaptive Support Weights (ASW &ndash; which is equivalent to AW in Fang&rsquo;s terminology) would perform the best (Chen, Ardabilian and Chen, 2015).&nbsp;</p>
# <p>Here, similarly to CW, cost is aggregated for both a&nbsp; reference and a target image pixel &nbsp;for a set of neighbouring pixels, though, their weight is dynamically calculated. A variety of methods has been proposed to calculate these dynamic weights (Hosni, Bleyer and Gelautz, 2013). One main &nbsp;characteristic of these various strategies that help differentiate between these methods is whether they performed in a symmetric or asymmetric manner. While the symmetric calculates a weight for both windows (left and right), asymmetric is only concerned with the left image window&rsquo;s weights. However, Hosni et al. concludes, there was no significant nor conclusive difference in accuracy between the two strategies in their comparison.</p>
# <p>Perhaps one of the most advanced techniques to calculate adaptive weights is trilateral filtering (Chen, Ardabilian and Chen, 2015). Chen et al.&rsquo;s ASW technique was based on&nbsp; three main rules: colour, spatial distance and boundary. According to the colour rule, if the centre pixel and a pixel&nbsp; in the support window around it have similar intensities, the probability of them having the same disparities is high, therefore this pixel&rsquo;s weight in the window should be high. According to the&nbsp; spatial distance rule the greater the distance of a pixel from the centre pixel is, the lower the &nbsp;probability of them having the same disparity. The proposed boundary rule, which also happened to be the novelty in their solution,&nbsp; states that if there is a boundary (edge i.e. discontinuity)&nbsp; between two pixels then the probability of them having the same disparity is smaller. The proposed weight function was</p>
# <table width="100%">
# <tbody>
# <tr>
# <td width="7%">
# <p>&nbsp;</p>
# </td>
# <td width="86%"><span class="MathJax_Preview" style="color: inherit;"><span id="MJXp-Span-378" class="MJXp-math MJXp-display"><span id="MJXp-Span-379" class="MJXp-msubsup"><span id="MJXp-Span-380" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;
class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">E</span><span id="MJXp-Span-467" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-468" class="MJXp-mtext">pq</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span class="MJXp-box MJXp-script"><span id="MJXp-Span-469" class="MJXp-msubsup"><span id="MJXp-Span-470" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">&gamma;</span><span id="MJXp-Span-471" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-472" class="MJXp-mi MJXp-italic">E</span></span></span></span></span></span></span></span></span></span></span></span><span id="MJXp-Span-473" class="MJXp-mtext"> ,</span></span></span></td>
# <td width="7%">
# <p>(2)</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>where&nbsp; q is a pixel in the support window centred around pixel p.&nbsp; &nbsp;is calculated as the Eucledian distance between the pixel intensities of p and q,&nbsp; &nbsp;is the geometric Eucledian distance between the x,y coordinates of&nbsp; p and q, while &nbsp;is a local energy model responsible for enforcing the boundary rule. The &ldquo;&rdquo; terms are arbitrary parameters used to adjust the strength of the respective constraints.&nbsp; They proposed the weight terms to be used in an asymmetric manner and as the&nbsp; multiplicator of the calculated cost at pixel q (See equation 3 below). Pixel &ldquo;q&rdquo; is a pixel in the support window around pixel &ldquo;p&rdquo;.</p>
# <table width="100%">
# <tbody>
# <tr>
# <td width="7%">
# <p>&nbsp;</p>
# </td>
# <td width="86%"><span class="MathJax_Preview" style="color: inherit;"><span id="MJXp-Span-474" class="MJXp-math MJXp-display"><span id="MJXp-Span-475" class="MJXp-msubsup"><span id="MJXp-Span-476" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">C</span><span class="MJXp-script-box" style="height: 1.86em; vertical-align: -0.64em;"><span class=" MJXp-script"><span style="margin-bottom: -0.25em;"><span id="MJXp-Span-479" class="MJXp-mrow"><span id="MJXp-Span-480" class="MJXp-mi MJXp-italic">A</span></span></span></span><span class=" MJXp-script"><span style="margin-top: -0.85em;"><span id="MJXp-Span-477" class="MJXp-mrow"><span id="MJXp-Span-478" class="MJXp-mi MJXp-italic">d</span></span></span></span></span></span><span id="MJXp-Span-481" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">(</span><span id="MJXp-Span-482" class="MJXp-mi MJXp-italic">p</span><span id="MJXp-Span-483" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">)</span><span id="MJXp-Span-484" class="MJXp-mo" style="margin-left: 0.333em; margin-right: 0.333em;">=</span><span id="MJXp-Span-485" class="MJXp-munderover"><span class="MJXp-over"><span id="MJXp-Span-494" class="MJXp-mrow" style="margin-right: 0px; margin-left: 0px;"></span><span class=""><span id="MJXp-Span-486" class="MJXp-mo" style="margin-left: 0.111em; margin-right: 0.167em;"><span class="MJXp-largeop">&sum;</span></span></span></span><span class=" MJXp-script"><span id="MJXp-Span-487" class="MJXp-mrow" style="margin-left: 0px;"><span id="MJXp-Span-488" class="MJXp-mi MJXp-italic">q</span><span id="MJXp-Span-489" class="MJXp-mo">&isin;</span><span id="MJXp-Span-490" class="MJXp-msubsup"><span id="MJXp-Span-491" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">w</span><span id="MJXp-Span-492" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-493" class="MJXp-mi MJXp-italic">p</span></span></span></span></span></span><span id="MJXp-Span-495" class="MJXp-mrow"><span id="MJXp-Span-496" class="MJXp-mi MJXp-italic">w</span><span id="MJXp-Span-497" class="MJXp-mrow"><span id="MJXp-Span-498" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">(</span><span id="MJXp-Span-499" class="MJXp-mi MJXp-italic">p</span><span id="MJXp-Span-500" class="MJXp-mo" style="margin-left: 0em; margin-right: 0.222em;">,</span><span id="MJXp-Span-501" class="MJXp-mtext">&nbsp;</span><span id="MJXp-Span-502" class="MJXp-mi MJXp-italic">q</span><span id="MJXp-Span-503" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">)</span></span><span id="MJXp-Span-504" class="MJXp-mo" style="margin-left: 0.267em; margin-right: 0.267em;">∙</span><span id="MJXp-Span-505" class="MJXp-msubsup"><span id="MJXp-Span-506" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">C</span><span id="MJXp-Span-507" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-508" class="MJXp-mi MJXp-italic">d</span></span></span><span id="MJXp-Span-509" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">(</span><span id="MJXp-Span-510" class="MJXp-mi MJXp-italic">q</span><span id="MJXp-Span-511" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">)</span></span></span></span></td>
# <td width="7%">
# <p>(3)</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>However, &nbsp;as a first step towards adaptive weights in this project, this was deviated from in three regards. In this alternative implementation the first key difference was that&nbsp; only the spatial and colour terms were used as part of the cost aggregation function. Secondly, instead of using the support&nbsp; weight (w(p,q))&nbsp; term as the multiplicator of the cost matrix within a support window , it was made part of the cost calculation. This decision was made so as to be able to store intermediary weight results and not have to recalculate them thus speeding up stereo correspondence. &nbsp;Thirdly, instead of the sum of&nbsp; the two&nbsp; weight terms, their product was used.&nbsp;This was suggested by (De-Maeztu, Villanueva and Cabeza, 2011). This proved to be more stable when it comes to the attempt of finding optimal parameters for this pipeline. This could be formulated as</p>
# <table width="100%">
# <tbody>
# <tr>
# <td width="7%">
# <p>&nbsp;</p>
# </td>
# <td width="86%"><span class="MathJax_Preview" style="color: inherit;"><span id="MJXp-Span-512" class="MJXp-math MJXp-display"><span id="MJXp-Span-513" class="MJXp-mi MJXp-italic">C</span><span id="MJXp-Span-514" class="MJXp-mrow"><span id="MJXp-Span-515" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">(</span><span id="MJXp-Span-516" class="MJXp-mi MJXp-italic">p</span><span id="MJXp-Span-517" class="MJXp-mo" style="margin-left: 0em; margin-right: 0.222em;">,</span><span id="MJXp-Span-518" class="MJXp-mi MJXp-italic">d</span><span id="MJXp-Span-519" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em;">)</span></span><span id="MJXp-Span-520" class="MJXp-mo" style="margin-left: 0.333em; margin-right: 0.333em;">=</span><span id="MJXp-Span-521" class="MJXp-munderover"><span class="MJXp-over"><span id="MJXp-Span-540" class="MJXp-mrow" style="margin-right: 0px; margin-left: 0px;"></span><span class=""><span id="MJXp-Span-522" class="MJXp-mo" style="margin-left: 0.111em; margin-right: 0.167em;"><span class="MJXp-largeop">&sum;</span></span></span></span><span class=" MJXp-script"><span id="MJXp-Span-523" class="MJXp-mrow" style="margin-left: 0px;"><span id="MJXp-Span-524" class="MJXp-mi MJXp-italic">q</span><span id="MJXp-Span-525" class="MJXp-mo">&isin;</span><span id="MJXp-Span-526" class="MJXp-msubsup"><span id="MJXp-Span-527" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">w</span><span id="MJXp-Span-528" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-529" class="MJXp-mi MJXp-italic">p</span></span></span><span id="MJXp-Span-530" class="MJXp-mo">,</span><span id="MJXp-Span-531" class="MJXp-mtext">&nbsp;</span><span id="MJXp-Span-532" class="MJXp-mtext">&nbsp;</span><span id="MJXp-Span-533" class="MJXp-mtext">&nbsp;</span><span id="MJXp-Span-534" class="MJXp-mi MJXp-italic">r</span><span id="MJXp-Span-535" class="MJXp-mo">&isin;</span><span id="MJXp-Span-536" class="MJXp-msubsup"><span id="MJXp-Span-537" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;
><span class="MJXp-box MJXp-script"><span id="MJXp-Span-610" class="MJXp-mrow"><span id="MJXp-Span-611" class="MJXp-mi">&Delta;</span></span><span id="MJXp-Span-612" class="MJXp-msubsup"><span id="MJXp-Span-613" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">S</span><span id="MJXp-Span-614" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-615" class="MJXp-mtext">dr</span></span></span></span><span class="MJXp-box" style="margin-top: -0.9em;"><span class="MJXp-denom"><span class="MJXp-box MJXp-script"><span id="MJXp-Span-616" class="MJXp-msubsup"><span id="MJXp-Span-617" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">&gamma;</span><span id="MJXp-Span-618" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-619" class="MJXp-mi MJXp-italic">s</span></span></span></span></span></span></span></span></span><span id="MJXp-Span-620" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em; vertical-align: -0.751em;"><span class="MJXp-right MJXp-scale4" style="font-size: 4.004em; margin-left: -0.17em;">)</span></span></span><span id="MJXp-Span-621" class="MJXp-mo" style="margin-left: 0.267em; margin-right: 0.267em;">∙</span><span id="MJXp-Span-622" class="MJXp-msubsup"><span id="MJXp-Span-623" class="MJXp-mi MJXp-italic" style="margin-right: 0.05em;">I</span><span id="MJXp-Span-624" class="MJXp-mrow MJXp-script" style="vertical-align: -0.4em;"><span id="MJXp-Span-625" class="MJXp-mtext">dr</span></span></span><span id="MJXp-Span-626" class="MJXp-mo" style="margin-left: 0em; margin-right: 0em; vertical-align: -0.751em;"><span class="MJXp-right MJXp-scale4" style="font-size: 4.004em; margin-left: -0.095em;">|,</span></span></span></span></span></span></td>
# <td width="7%">
# <p>(4)</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>where w<sub>p</sub> and w<sub>d </sub>&nbsp;denote the support windows around the left image&rsquo;s pixel p and the right image&rsquo;s pixel d. q and r denote pixel coordinates in the support window while I stands for pixel intensity. However, the version where the weight terms were added together was tested as well.</p>
# <h2 id="Method">Method</h2>
# <p>As it has been suggested above, two variants of the proposed bilateral filtering term was tested: one that used the &nbsp;product of the weight terms and one that used the sum of the weight terms.</p>
# <p>First, in order to mitigate the effects of ill-parameter configuration and reduce the time needed to demonstrate relevant results, the two algorithm variants were tested on the Middlebury 2003 dataset&rsquo;s quarter resolution scenes in grayscale mode. The methodology was similar to the one followed for &nbsp;<a href="ALG_005_EXP_001-PatchMatch-2003.ipynb" target="_blank" rel="noopener">ALG_005_EXP_001</a>. However, here, first, a range of the parameters were tested with a relatively big step (20-50). Then, the ranges with the pest results were tested again, but with &nbsp;smaller steps (5-10). This way local minimums or locations near local minimums were though to have found. Notebook versions of these experiments can be found at <a href="ALG_006_EXP_001-Bilateral_product_2003.ipynb" target="_blank" rel="noopener">ALG_006_EXP_001-Bilateral_product_2003</a> and <a href="ALG_006_EXP_002-Bilateral_summed_2003.ipynb" target="_blank" rel="noopener">ALG_006_EXP_002-Bilateral_summed_2003</a>. Separate written analysis was not created for these experiments as it was assumed that their results would be misleading due to the limited size of the Middlebury 2003 dataset.</p>
# <p>Therefore, informed by these two initial experiments, the Middlebury 2014 dataset&rsquo;s training images were tested at quarter resolution in grayscale for a set of parameters thought to be near the aforementioned local minimums. For the list of parameters please see Table 1.</p>
# <p>Table 1: Parameter list for the last three conducted experiments (ALG_005_EXP_003, ALG_006_EXP_001, ALG_006_EXP_003-Bilateral_product_2014-VIS, ALG_006_EXP_004-Bilateral_summed_2014-VIS)</p>
# <table width="601">
# <tbody>
# <tr>
# <td width="123">
# <p>Algorithm variant</p>
# </td>
# <td width="67">
# <p>Alias</p>
# </td>
# <td width="132">
# <p>Support window dimensions</p>
# </td>
# <td width="53">
# <p>Match values</p>
# </td>
# <td width="57">
# <p>&gamma;<sub>c</sub></p>
# </td>
# <td width="34">
# <p>&gamma;<sub>s</sub></p>
# </td>
# </tr>
# <tr>
# <td width="123">
# <p>truncated - bilateral-sum</p>
# </td>
# <td width="67">
# <p>trunc_plusblg</p>
# </td>
# <td width="132">
# <p>5x7</p>
# </td>
# <td width="53">
# <p>30-35</p>
# </td>
# <td width="57">
# <p>1</p>
# </td>
# <td width="34">
# <p>5</p>
# </td>
# </tr>
# <tr>
# <td width="123">
# <p>bilateral-product-weights</p>
# </td>
# <td width="67">
# <p>blg</p>
# </td>
# <td width="132">
# <p>3x3, 3x5, 5x7, 7x3</p>
# </td>
# <td width="53">
# <p>30, 40, 50</p>
# </td>
# <td width="57">
# <p>8, 10, 12</p>
# </td>
# <td width="34">
# <p>90</p>
# </td>
# </tr>
# <tr>
# <td width="123">
# <p>bilateral-summed weights</p>
# </td>
# <td width="67">
# <p>plusblg</p>
# </td>
# <td width="132">
# <p>3x3, 3x5, 5x7, 7x3</p>
# </td>
# <td width="53">
# <p>30, 40, 45, 55</p>
# </td>
# <td width="57">
# <p>1-7</p>
# </td>
# <td width="34">
# <p>1,2</p>
# </td>
# </tr>
# <tr>
# <td width="123">
# <p>constant window</p>
# </td>
# <td width="67">
# <p>bm</p>
# </td>
# <td width="132">
# <p>1x1, 1x3, 1x5, 1x7, 3x1, 3x3, 3x5, 3x7, 5x1, 5x3, 7x1, 7x3, 7x5, 9x3, 9x5, 9x7, 11x3, 11x5, 13x3, 13x5, 13x7, 15x3, 15x5, 15x7, 15x9</p>
# </td>
# <td width="53">
# <p>10-110 with a step of 20</p>
# </td>
# <td width="57">
# <p>-</p>
# </td>
# <td width="34">
# <p>-</p>
# </td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <p>Then, since significant difference was not identified between the summed and product weight approaches (<a href="ALG_006_EXP_003-Bilateral_product_2014-VIS.ipynb" target="_blank" rel="noopener">ALG_006_EXP_003-Bilateral_product_2014-VIS</a>, <a href="ALG_006_EXP_004-Bilateral_summed_2014-VIS.ipynb" target="_blank" rel="noopener">ALG_006_EXP_004-Bilateral_summed_2014-VIS</a>), a comparative analysis was conducted with regards to the experiments listed in Table 1.While specific objective of this project was to experiment on raw outputs of the algorithm, due to the large number of horizontal structural noise observed the disparity maps were additionally benchmarked after applying a median filter of 5 (width and height).</p>
# <h2 id="Discussion-and-results">Discussion and results</h2>
# <p>Compared to the results logged &nbsp;during the experiment on constant weight windows (CW) &nbsp;(ALG_005_EXP_001) there had been a 17% increase in accuracy (best CW: 46.01%, best bilateral: 29.4%) overall when analysing bad4 results.&nbsp;This would place the algorithm&rsquo;s performance at around the 41<sup>st</sup> &nbsp;place in the Middlebury Evaluation Framework&rsquo;s chart (Scharstein and Hirschm&uuml;ller, 2014) already overtaking some deep learning based solutions (DTS - (Bapat and Frahm, 2018), iResNet - (Liang <em>et al.</em>, 2017)).</p>
# <p>Significant difference in terms of accuracy between the summed and product weight term methods was identified. However, &nbsp;the discrepancies in accuracy were thought to be on the account of more favourably selected and tested parameters for the summed version which manifested in a 4% difference overall. The greatest improvements in accuracy between the constant and bilateral weighted methods were &nbsp;achieved on the scenes Adirondack (27%) , ArtL (21%), MotorcycleE (51%) and PianoL (21%). This suggested that the application of bilateral weights (especially using the &ldquo;plus termed&rdquo; version) made the algorithm more robust towards lighting and exposure variations within a scene. This was an interesting result since this pipeline only considered pixel intensities, not gradients (which are thought to be more invariant when lighting and exposure conditions change (De-Maeztu, Villanueva and Cabeza, 2011)).&nbsp; The worst improvements were observed w.r.t. the scene Playtable. The reason behind this was thought to be the mainly diagonal orientation of edged within that scene which the algorithm was not able to interpret properly.</p>
# <p>Informed by visual assessment, there was an increased amount of horizontal structural noise observable (Boyat and Joshi, 2015). This noise often manifested in a few pixel radius black pixel patch. Additionally, errors were thought to have manifested in streaking artefacts as well. &nbsp;The most severely affected scenes were MotorcycleE, Piano, PianoL, Pipes, Playroom and Playtable scenes.</p>
# <p>Having observed the aforementioned noise, the best disparity maps were re-evaluated after applying a 5x5 median filter on them. The best improvement achieved was with regard to the &ldquo;product termed&rdquo; version, 3%, while the opposite effect was observable when it comes to the &ldquo;sum termed&rdquo; version. It was thought that should there had been a more favourable parameter setting for the &ldquo;product termed&rdquo; version, the observations would have aligned and a median filtering would have actually made its performance worse.</p>
# <p>Please note, that experiments so far were performed on the training dataset and while the evaluation (test) dataset was thought to pose similar challenges, the validity of the comparisons to the Middlebury Evaluation Framework&rsquo;s 2014 version were not actually tested. Though, they were though to be good approximations.</p>
# <h2 id="Conclusion">Conclusion</h2>
# <p>There was no statistically relevant difference observed between the &ldquo;summed&rdquo; and the &ldquo;product&rdquo; variants. &nbsp;The achieved improvement with respect to the previous iteration, where constant weight (CW) windows were used, was 17%. &nbsp;Greatest improvements were achieved with regards to scenes of lighting or exposure variant. Horizontal structural noise and a large number of streaking artefacts were observed upon visual analysis. The "plus termed" version outperformed the "product termed" one, though, it was thought to be on the account on more favourable parameter selection.</p>
# <h2 id="References">References</h2>
# <ol>
# <li>
# <p>Bapat, A. and Frahm, J.-M. (2018) &lsquo;The Domain Transform Solver&rsquo;, (1), pp. 1&ndash;9. Available at: http://arxiv.org/abs/1805.04590 (Accessed: 3 August 2020).</p>
# </li>
# <li>
# <p>Boyat, A. K. and Joshi, B. K. (2015) &lsquo;A Review Paper : Noise Models in Digital Image Processing&rsquo;, <em>Signal &amp; Image Processing : An International Journal</em>. Academy and Industry Research Collaboration Center (AIRCC), 6(2), pp. 63&ndash;75. doi: 10.5121/sipij.2015.6206.</p>
# </li>
# <li>Chen, D., Ardabilian, M. and Chen, L. (2015) &lsquo;A fast trilateral filter-based adaptive support weight method for stereo matching&rsquo;, <em>IEEE Transactions on Circuits and Systems for Video Technology</em>. Institute of Electrical and Electronics Engineers Inc., 25(5), pp. 730&ndash;743. doi: 10.1109/TCSVT.2014.2361422.</li>
# <li>De-Maeztu, L., Villanueva, A. and Cabeza, R. (2011) &lsquo;Stereo matching using gradient similarity and locally adaptive support-weight&rsquo;, <em>Pattern Recognition Letters</em>. North-Holland, 32(13), pp. 1643&ndash;1651. doi: 10.1016/j.patrec.2011.06.027.</li>
# <li>Fang, J. <em>et al.</em> (2012) &lsquo;Accelerating cost aggregation for real-time stereo matching&rsquo;, in <em>Proceedings of the International Conference on Parallel and Distributed Systems - ICPADS</em>, pp. 472&ndash;481. doi: 10.1109/ICPADS.2012.71.</li>
# <li>Hamzah, R. A. and Ibrahim, H. (2016) &lsquo;Literature Survey on Stereo Vision Disparity Map Algorithms&rsquo;, <em>Journal of Sensors</em>, 2016, pp. 1&ndash;23. doi: 10.1155/2016/8742920.</li>
# <li>Hosni, A., Bleyer, M. and Gelautz, M. (2013) &lsquo;Secrets of adaptive support weight techniques for local stereo matching&rsquo;, <em>Computer Vision and Image Understanding</em>. Academic Press, 117(6), pp. 620&ndash;632. doi: 10.1016/j.cviu.2013.01.007.</li>
# <li>Liang, Z. <em>et al.</em> (2017) &lsquo;Learning for Disparity Estimation through Feature Constancy&rsquo;, <em>Proceedings of the IEEE Computer Society Conference on Computer Vision and Pattern Recognition</em>. IEEE Computer Society, pp. 2811&ndash;2820. Available at: http://arxiv.org/abs/1712.01039 (Accessed: 2 August 2020).</li>
# <li>Madeo, S. <em>et al.</em> (2016) &lsquo;An optimized stereo vision implementation for embedded systems: application to RGB and infra-red images&rsquo;, <em>Journal of Real-Time Image Processing</em>, 12(4), pp. 725&ndash;746. doi: 10.1007/s11554-014-0461-7.</li>
# <li>Scharstein, D. and Hirschm&uuml;ller, H. (2014) <em>Middlebury Stereo Evaluation - Version 3</em>, <em>Middlebury Stereo Vision Pages</em>. Available at: http://vision.middlebury.edu/stereo/eval3/ (Accessed: 1 June 2020).</li>
# </ol>

# %%
import pandas as pd
import ipywidgets as widgets
import numpy as np
import sys
import os

sys.path.append(os.path.join("..", ".."))
import glob
import cv2

import plotly.graph_objs as go
import plotly.express as px
from ipywidgets import HBox, VBox, Button

from components.utils import plotly_helpers as ph
from components.utils import utils as u

# %%
available_metrix = ['abs_error',
       'mse', 'avg', 'eucledian', 'bad1', 'bad2', 'bad4', 'bad8']

metrics_selector = widgets.Dropdown(
    options=[(m,m) for m in available_metrix],
    description='Metric:',
    value="bad4"
)


nonoccluded = widgets.Dropdown(
    options=[("yes", False), ("No", True)],
    description='Nonoccluded:'
)

# %% [markdown]
# ### Please select metrics and whether occlusions are counted as errors

# %%
VBox([metrics_selector, nonoccluded])

# %% [markdown]
# ### Loading the data and building the plots

# %%
# best_results.csv

selected_file = os.path.join("..","..", "benchmarking", "MiddEval", "custom_log", "best_results.csv")
#selected_file = "./fixed_csv2.csv"
df = ph.load_n_clean(selected_file)

##Filtering to selected occlusion parameter

df = df[df["are_occlusions_errors"]==nonoccluded.value]
df.sort_values(by=["scene", "match", "h", "w"], inplace=True)

# %%
### Dashboard 1


from ipywidgets import Image, Layout

img_widget = Image(value=df["loaded_imgs"].iloc[0], 
                   layout=Layout(height='375px', width='450px'))

fig_a = ph.get_figure_widget (df, "scene", metrics_selector.value, 
                           "Scene w.r.t."+metrics_selector.value)
fig_b = ph.get_figure_widget (df, "match", "kernel_size", "Kernel sizes w.r.t. match values")


figs = [fig_a, fig_b]
ph.bind_hover_function(figs, img_widget, df)
ph.bind_brush_function(figs, df)

button = ph.get_reset_brush_button(figs)
dashboard1 = VBox([button, fig_a,
                  HBox([img_widget, fig_b])])


### Dashboard 2

df.sort_values(by=["experiment_id"])
traced_fig_1, dfs_1 = ph.get_figure_widget_traced(df, "scene", metrics_selector.value, "experiment_id")

traced_fig_widget_1 = go.FigureWidget(traced_fig_1)



traced_fig_1_imw_1 = Image(value=df["loaded_imgs"].iloc[0], 
                   layout=Layout(height='375px', width='450px'))
traced_fig_1_imw_2 = Image(value=df["loaded_gts"].iloc[0], 
                   layout=Layout(height='375px', width='450px'))

#figs, img_widget, selected_scene_df
ph.bind_hover_function2([traced_fig_widget_1], traced_fig_1_imw_1, dfs_1, img_widget_groundtruth=traced_fig_1_imw_2)


turn_the_lights_on = ph.get_dropdown_widget(["On", "Off"], label="Turn plots:", values = [True, False])

ph.bind_dropdown_switch_traces_fn(turn_the_lights_on, traced_fig_widget_1)

dashboard2 = VBox([turn_the_lights_on, traced_fig_widget_1, HBox([traced_fig_1_imw_1,traced_fig_1_imw_2])])


### Dashboard 3


traced_fig_2, dfs_2 = ph.get_figure_widget_traced(df, "experiment_id", metrics_selector.value, "scene")

traced_fig_widget_2 = go.FigureWidget(traced_fig_2)

traced_fig_2_imw_1 = Image(value=df["loaded_imgs"].iloc[0], 
                   layout=Layout(height='375px', width='450px'))
traced_fig_2_imw_2 = Image(value=df["loaded_gts"].iloc[0], 
                   layout=Layout(height='375px', width='450px'))



#figs, img_widget, selected_scene_df
ph.bind_hover_function2([traced_fig_widget_2], traced_fig_2_imw_1, dfs_2, img_widget_groundtruth=traced_fig_2_imw_2)

turn_the_lights_on_2 = ph.get_dropdown_widget(["On", "Off"], label="Turn plots:", values = [True, False])

ph.bind_dropdown_switch_traces_fn(turn_the_lights_on_2, traced_fig_widget_2)


dashboard3 = VBox([turn_the_lights_on_2, traced_fig_widget_2, HBox([traced_fig_2_imw_1,traced_fig_2_imw_2])])

# %% [markdown]
# ### To aid interaction with the plots, the best results in a tabular form are displayed below

# %%
pd.pivot_table(df, index = ["experiment_id", "kernel_size", "match"], values = "bad4", aggfunc=np.mean).sort_values(by="bad4").head(4)
# Out:
#                                                                           bad4
# experiment_id                                      kernel_size match
# trunc_plusblg_30_5x7no_infmge_30_-9_-1_gc_5_gs_... 5x7         30     0.268293
# plusblg_45_5x7gc_5_gs_1_alph_0                     5x7         45     0.294960
# blg_40_5x7gc_8_gs_90_alph_0                        5x7         40     0.336915
# bm_30_9x3                                          9x3         30     0.460599

# %%
df.pivot_table(index = "experiment_id", columns="scene", values = "bad4", aggfunc=np.min).head(10)
# Out:
# scene                                               Adirondack      ArtL  \
# experiment_id
# blg_40_5x7gc_8_gs_90_alph_0                           0.203030  0.232686
# bm_30_1x1                                             0.512256  0.619496
# bm_30_9x3                                             0.452485  0.483601
# plusblg_45_5x7gc_5_gs_1_alph_0                        0.190174  0.245474
# trunc_plusblg_30_5x7no_infmge_30_-9_-1_gc_5_gs_...    0.162497  0.212571
#
# scene                                               Jadeplant  Motorcycle  \
# experiment_id
# blg_40_5x7gc_8_gs_90_alph_0                          0.628386    0.152385
# bm_30_1x1                                            0.643227    0.305835
# bm_30_9x3                                            0.637492    0.177582
# plusblg_45_5x7gc_5_gs_1_alph_0                       0.357256    0.152771
# trunc_plusblg_30_5x7no_infmge_30_-9_-1_gc_5_gs_...   0.313128    0.139842
#
# ...

# %% [markdown]
# ### Dashboard 1: Scene w.r.t. {metric} (selection plot)
# <ol>
#     <li>The following figure allows to use the "lasso" tool as a tool of selection.</li>
#     <li>As a result, the relevant datapoints and their corresponding values in the figure in the bottom right corner will be highlighted.</li>
#     <li>Pressing the "clear selection" button will reset the figure.</li>
#     <li> Additionally, if a data point is hovered, the corresponding disparity output value will be displayed in the bottom right corner.</li>
#
# </ol>

# %%
dashboard1
# Out:
# ...
#     'data': [{'custo…

# %% [markdown]
# ### Dashboard 2: Scenes w.r.t. {metric} with color coded "epochs"
# An "epoch" in this context means an experiment with the same settings evaluated across every scene in the Middlebury 2004 training dataset.<br>
# <ol>
#     <li>The following figure allows to turn all the plots on and off</li>
#     <li>Additionally, their visibiliy can also be handled by interacting with their legend entries on the right side of the plot.
#     </li>
#     <li> Therefore custom comparison can be made between different scenes, kernel sizes and match values. </li>
#     <li> The figure in the bottom left corner shows the corresponding disparity map. </li>
#     <li> The figure in the bottom right corner shows the corresponding ground truth disparity map. </li>
# </ol>

# %%
dashboard2

# %% [markdown]
# ### Dashboard 3: "Epoch" w.r.t. {metric} with color coded scenes
# An "epoch" in this context means an experiment with the same settings evaluated across every scene in the Middlebury 2004 training dataset.<br>
# <ol>
#     <li>The following figure allows to turn all the plots on and off</li>
#     <li>Additionally, their visibiliy can also be handled by interacting with their legend entries on the right side of the plot.
#     </li>
#     <li> Therefore custom comparison can be made between different scenes, kernel sizes and match values. </li>
#     <li> The figure in the bottom left corner shows the corresponding disparity map. </li>
#     <li> The figure in the bottom right corner shows the corresponding ground truth disparity map. </li>
# </ol>

# %%
dashboard3

# %% [markdown]
# ### Tesing the effect of applying a 5x5 median blur

# %%
import cv2
import pandas as pd
import numpy as np
import project_helpers
import os
from components.utils.Metrix import Wrapper as me
from components.utils import utils as u

file_path = os.path.join(project_helpers.get_project_dir(), "benchmarking","MiddEval", "custom_log","best_results.csv" )

pd = pd.read_csv(file_path)

gt_mask = "disp0GT.pfm"
occ_mask = "mask0nocc.png"

average = dict(bm_30_9x3=0, blg_40_5x7gc_8_gs_90_alph_0=0, plusblg_45_5x7gc_5_gs_1_alph_0=0, bm_30_1x1=0)
average["trunc_plusblg_30_5x7no_infmge_30_-9_-1_gc_5_gs_1_a_30"] = 0
for img_path, scene, exp_id in pd[["image_filename", "scene", "experiment_id"]].values:

    root = project_helpers.get_project_dir()
    img_full_path = os.path.join(project_helpers.fix_win_rel_paths(img_path))
    img_raw = cv2.imread(img_full_path, cv2.IMREAD_GRAYSCALE)
    img_temp = cv2.medianBlur(img_raw, 5)
    dirname = os.path.dirname(img_full_path)
    
    gt_path = os.path.join(dirname, gt_mask)
    occ_path = os.path.join(dirname, occ_mask)
    
    
    gt = u.load_pfm(gt_path)[0]
    occ = cv2.imread(occ_path, cv2.IMREAD_GRAYSCALE)
    
    evals = me.evaluate_over_all(img_temp, gt*4, occ, occlusions_counted_in_errors = False)
    average[exp_id]+=evals[2]
    print("{2}:Bad4 for scene {0}: {1:.4f}".format(scene, evals[2], exp_id))

for k, v in average.items():
    print("{0}: {1}".format(k,v/15))
# Out:
# bm_30_9x3:Bad4 for scene Motorcycle: 0.1661
# bm_30_9x3:Bad4 for scene Teddy: 0.1821
# bm_30_9x3:Bad4 for scene PlaytableP: 0.2684
# bm_30_9x3:Bad4 for scene Pipes: 0.2978
# bm_30_9x3:Bad4 for scene Playtable: 0.3457
# bm_30_9x3:Bad4 for scene Recycle: 0.3896
# bm_30_9x3:Bad4 for scene Piano: 0.4328
# bm_30_9x3:Bad4 for scene Adirondack: 0.4452
# bm_30_9x3:Bad4 for scene Playroom: 0.4449
# bm_30_9x3:Bad4 for scene Shelves: 0.4736
# bm_30_9x3:Bad4 for scene ArtL: 0.4728
# bm_30_9x3:Bad4 for scene Jadeplant: 0.6377
# bm_30_9x3:Bad4 for scene Vintage: 0.6424
# bm_30_9x3:Bad4 for scene PianoL: 0.7257
# bm_30_9x3:Bad4 for scene MotorcycleE: 0.8366
# blg_40_5x7gc_8_gs_90_alph_0:Bad4 for scene Teddy: 0.1025
# blg_40_5x7gc_8_gs_90_alph_0:Bad4 for scene Motorcycle: 0.1305
# blg_40_5x7gc_8_gs_90_alph_0:Bad4 for scene Adirondack: 0.1709
# blg_40_5x7gc_8_gs_90_alph_0:Bad4 for scene Recycle: 0.1982
# blg_40_5x7gc_8_gs_90_alph_0:Bad4 for scene ArtL: 0.2135
# ...
