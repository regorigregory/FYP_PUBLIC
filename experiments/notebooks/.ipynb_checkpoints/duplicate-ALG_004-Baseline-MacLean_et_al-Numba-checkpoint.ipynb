# %%
import sys
import os
sys.path.append("../../")

ROOT_PATH = os.path.join("..", "..")
EXPERIMENT_TITLE = "EXP_000-Baseline_Numba_Q"

INIT_METHOD = "original"
DATASET = "middlebury"

DATASET_FOLDER = os.path.join(ROOT_PATH, "datasets", DATASET)
LOG_FOLDER = os.path.join(ROOT_PATH, "experiments", "logs")
CSV_FILEPATH = os.path.join(LOG_FOLDER, EXPERIMENT_TITLE+".csv")
IMG_RES = "450X375"
PREPROCESSING_METHOD = "None"
KERNEL_SIZE = 1
KERNEL_SPEC = "None"

SCENES = ["teddy", "cones"]
SIZE=""
YEAR= 2003
EXP_PARAMS = dict()

# %%
###################################################################
# Built-in modules ################################################
###################################################################

import numpy as np
import imp
import cv2
import os
import matplotlib.pyplot as plt
import gc
from components.utils.CSVWriter2 import Wrapper as l
from components.utils.Metrix import Wrapper as me
import math
import time
import glob

###################################################################
# Custom modules ##################################################
###################################################################

from components.matchers.ParallelMatcherNWMacLean import Wrapper as m
from components.utils.SimpleProgressBar import SimpleProgressBar
from components.utils import utils as u
from components.utils import plot_utils as plu
from components.utils.CSVWriter2 import Wrapper as csv

###################################################################
# Dataset specific modules#########################################
###################################################################

from components.utils import middlebury_utils as mbu
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dbc2c29cda29> in <module>
#       9 import matplotlib.pyplot as plt
#      10 import gc
# ---> 11 from components.utils.CSVWriter2 import Wrapper as l
#      12 from components.utils.Metrix import Wrapper as me
#      13 import math
#
# ModuleNotFoundError: No module named 'components'

# %% [markdown]
# #  Loading the dataset and visualising the results

# %%
loaded_imgs_and_paths = list(mbu.get_images(DATASET_FOLDER, YEAR, scene) for scene in SCENES)

for im, path in loaded_imgs_and_paths:
    filenames = list(os.path.split(p)[-1] for p in path)
    plu.plot_images(im, filenames)
# Out:
# ['im2.png', 'im6.png', 'disp2.png', 'teddy_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\teddy\im2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\im6.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\teddy_nonocc.png
# ['im2.png', 'im6.png', 'disp2.png', 'cones_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\cones\im2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\im6.png
# ..\..\datasets\middlebury\middlebury_2003\cones\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\cones_nonocc.png

# %% [markdown]
# # The addition of occluded areas to the pristine groundtruth images

# %%
###################################################################
# 2. Occluded areas are added to the groundtruths #################
###################################################################

nonocc_gts = list()
for imgs, paths in loaded_imgs_and_paths:
    temp = mbu.add_masks_to_raw_disparity(imgs[2], imgs[3])
    nonocc_gts.append(mbu.add_masks_to_raw_disparity(imgs[2], imgs[3]))
plu.plot_images(nonocc_gts, ["teddy_nonocc_gt", "cones_nonocc_gt"])

# %% [markdown]
# # Benchmarking and evaluation

# %%
###################################################################
# 3.1 Initialising hyperparameters and matcher#####################
###################################################################

csv_logger = csv(CSV_FILEPATH, default_header=False)
csv_logger.set_header_function(csv_logger.get_header_v3)
csv_logger.write_csv_header()
csv_logger.set_line_function(csv.format_stereo_matching_results_v2)

MATCH = 60
GAP = -20
EGAP = -1


EXP_PARAMS = {"experiment_id":EXPERIMENT_TITLE, "match": MATCH,"gap":GAP,"egap":EGAP,\
                  "algo":str(m.__module__), "init_method":"default","dataset":DATASET,\
                  "preprocessing_method":"None","kernel_size":1,"kernel_spec":"None"}
# Out:
# Directory '..\..\experiments\logs' already exists.

# %%
###################################################################
# 3.2 Matching ####################################################
###################################################################

results = []


matcher = m(MATCH, GAP, EGAP)
EXP_PARAMS["init_method"] = "maclean_et_al"
for i, scene in enumerate(SCENES):
    EXP_PARAMS["scene"] = scene
    EXP_PARAMS["image_filename"] = IMAGE_FILENAME = loaded_imgs_and_paths[i][1][0]
    EXP_PARAMS["img_res"] = "{0}x{1}".format(loaded_imgs_and_paths[i][0][1].shape[1], loaded_imgs_and_paths[i][0][1].shape[0])  
    occ = loaded_imgs_and_paths[i][0][3]
    gt = loaded_imgs_and_paths[i][0][2]
    
    matcher.initialize(loaded_imgs_and_paths[i][0][0], loaded_imgs_and_paths[i][0][1])
    
    tic = time.time()
    matcher = u.executeParallelMatching(matcher)
    toc=time.time()
    
    EXP_PARAMS["runtime"] = toc-tic
    
    disp = matcher.lastDisparity
    disp = disp

    EXP_PARAMS["are_occlusions_errors"] = ARE_OCCLUSIONS_ERRORS = True
    
    EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
    BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, occ, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

    csv_logger.append_new_sm_results(EXP_PARAMS, csv.get_header_v3())

    EXP_PARAMS["are_occlusions_errors"] = ARE_OCCLUSIONS_ERRORS = False
    EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
    BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, occ, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

    csv_logger.append_new_sm_results(EXP_PARAMS, csv.get_header_v3())
    results.append(disp)
# Out:
# Matcher has been initialized.
# Aligning scanlines has finished. It has taken: 39.43 seconds.
# Matcher has been initialized.
# Aligning scanlines has finished. It has taken: 50.16 seconds.

# %%
SAVE_PATH  = os.path.join(ROOT_PATH, "experiments", "disparities", EXPERIMENT_TITLE)
saved_image_names = []
for result in results:
    temp_path = u.save_disparity(SAVE_PATH, result)
    saved_image_names.append(os.path.split(temp_path)[-1])

# %%
plu.plot_images(results, saved_image_names)

# %%
from skimage import filters
from skimage.morphology import disk, square

# %%
mf = square(5)
MULTIPLIER = 4
OFFSET = 0
BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all((results[0]+OFFSET)*MULTIPLIER, loaded_imgs_and_paths[0][0][2], loaded_imgs_and_paths[0][0][3], occlusions_counted_in_errors = True)
formatted_str = "raw (teddy): bad1:{0:.4f} bad2:{1:.4f} BAD8:{2:.4f}".format(BAD1, BAD2, BAD8)
print(formatted_str)

BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all((results[1]+OFFSET)*MULTIPLIER, loaded_imgs_and_paths[1][0][2], loaded_imgs_and_paths[1][0][3], occlusions_counted_in_errors = True)
formatted_str = "raw (cones): bad1:{0:.4f} bad2:{1:.4f} BAD8:{2:.4f}".format(BAD1, BAD2, BAD8)
print(formatted_str)



median_results = [filters.median(r, mf) for r in results]

BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(median_results[0], loaded_imgs_and_paths[0][0][2], loaded_imgs_and_paths[0][0][3], occlusions_counted_in_errors = True)
formatted_str = "median (teddy): bad1:{0:.4f} bad2:{1:.4f} BAD8:{2:.4f}".format(BAD1, BAD2, BAD8)
print(formatted_str)

BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(median_results[1], loaded_imgs_and_paths[1][0][2], loaded_imgs_and_paths[1][0][3], occlusions_counted_in_errors = True)
formatted_str = "median (cones): bad1:{0:.4f} bad2:{1:.4f} BAD8:{2:.4f}".format(BAD1, BAD2, BAD8)

print(formatted_str)
plu.plot_images(median_results, ["teddy", "cones"])
# Out:
# raw (teddy): bad1:0.6213 bad2:0.4805 BAD8:0.1764
# raw (cones): bad1:0.6312 bad2:0.5313 BAD8:0.2396
# median (teddy): bad1:0.9196 bad2:0.9196 BAD8:0.9192
# median (cones): bad1:0.9223 bad2:0.9221 BAD8:0.9213

# %%
from components.utils import visualisation_utils as vu
import imp

# %%
vu.compare_histograms(results[0], nonocc_gts[0])

# %%
vu.compare_histograms(median_results[0], nonocc_gts[0])

# %%
vu.show_hit_and_miss(results[0], nonocc_gts[0], threshold=5)

# %%
vu.show_difference(results[0], nonocc_gts[0])

# %%
imp.reload(vu)
# %matplotlib notebook
loaded_imgs_and_paths_colored = list(mbu.get_images(DATASET_FOLDER, YEAR, scene, grayscale=False) for scene in SCENES)
# Out:
# ['im2.png', 'im6.png', 'disp2.png', 'teddy_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\teddy\im2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\im6.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\teddy_nonocc.png
# ['im2.png', 'im6.png', 'disp2.png', 'cones_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\cones\im2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\im6.png
# ..\..\datasets\middlebury\middlebury_2003\cones\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\cones_nonocc.png

# %%
vu.plod3d_with_img_surface(nonocc_gts[0], finess=5, surface=loaded_imgs_and_paths_colored[0][0][0])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hit_mask = np.abs(results[0]-nonocc_gts[0])>5
img_to_modify = loaded_imgs_and_paths_colored[0][0][0]
img_to_modify[hit_mask, :]=0
vu.plod3d_with_img_surface(nonocc_gts[0], finess=5, surface=img_to_modify)
# Out:
# <img src="data:image/png;base64,..." width="640">
