# %%
###################################################################
# Built-in modules ################################################
###################################################################
import sys
import os

sys.path.append("../../")

import numpy as np
import imp
import cv2
import os
import matplotlib.pyplot as plt
import gc

import math
import time
import glob

###################################################################
# Custom modules ##################################################
###################################################################

from components.matchers.NumbaPatchMatcher import Wrapper as m
from components.utils.SimpleProgressBar import SimpleProgressBar
from components.utils import utils as u
from components.utils import plot_utils as plu
from components.utils.CSVWriter2 import Wrapper as csv
from components.utils.Metrix import Wrapper as me

###################################################################
# Dataset specific modules#########################################
###################################################################

from components.utils import middlebury_utils as mbu

# %%
ROOT_PATH = os.path.join("..", "..")
EXPERIMENT_TITLE = "ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba-rgb"

INIT_METHOD = "maclean"
DATASET = "middlebury"

DATASET_FOLDER = os.path.join(ROOT_PATH, "datasets", DATASET)
LOG_FOLDER = os.path.join(ROOT_PATH, "experiments", "logs")
CSV_FILEPATH = os.path.join(LOG_FOLDER, EXPERIMENT_TITLE+".csv")
IMG_RES = "450X375"
PREPROCESSING_METHOD = "None"
KERNEL_SIZE = 1
KERNEL_SPEC = "None"

SCENES = ["teddy", "cones"]
SIZE=""
YEAR= 2003
EXP_PARAMS = dict()

# %% [markdown]
# #  Loading the dataset and visualising the results

# %%
loaded_imgs_and_paths = list(mbu.get_images(DATASET_FOLDER, YEAR, scene, grayscale=False) for scene in SCENES)

for im, path in loaded_imgs_and_paths:
    filenames = list(os.path.split(p)[-1] for p in path)
    plu.plot_images(im, filenames)
# Out:
# ['im2.png', 'im6.png', 'disp2.png', 'teddy_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\teddy\im2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\im6.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\teddy_nonocc.png
# ['im2.png', 'im6.png', 'disp2.png', 'cones_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\cones\im2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\im6.png
# ..\..\datasets\middlebury\middlebury_2003\cones\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\cones_nonocc.png

# %% [markdown]
# # Benchmarking and evaluation

# %%
###################################################################
# Initialising hyperparameters and matcher#####################
###################################################################

csv_logger = csv(CSV_FILEPATH, default_header=False)
csv_logger.set_header_function(csv_logger.get_header_v3)
csv_logger.write_csv_header()
csv_logger.set_line_function(csv.format_stereo_matching_results_v2)

MATCH = 30
GAP = -20
EGAP = -1


EXP_PARAMS = {"experiment_id":EXPERIMENT_TITLE, "match": MATCH,"gap":GAP,"egap":EGAP,\
                  "algo":str(m.__module__), "init_method":"default","dataset":DATASET,\
                  "preprocessing_method":"None","kernel_size":1,"kernel_spec":"None"}
# Out:
# File ..\..\experiments\logs\ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba-rgb.csv already exists, header has not been written.

# %%
###################################################################
# Matching ####################################################
###################################################################

results = []

EXP_PARAMS["init_method"] = "maclean_et_al"

patches = [
           np.ones((5,3)), np.ones((7,3)),
           np.ones((9,3)), np.ones((11,3)),
           np.ones((13,3)), np.ones((15,3))
          ]

matcher = m(MATCH, GAP, EGAP)
progress_bar = SimpleProgressBar.get_instance()

progress_counter = 1
steps_to_be_taken = len(SCENES)*len(patches)*4


SAVE_PATH  = os.path.join(ROOT_PATH, "experiments", "disparities", EXPERIMENT_TITLE)

saved_image_names = []
results = []

# %%
for match_value in range(10,40, 10):
    for p in patches:
        for i, scene in enumerate(SCENES):
            EXP_PARAMS["match"] = MATCH = match_value
            matcher = m(MATCH, GAP, EGAP)
            
            EXP_PARAMS["scene"] = scene
            EXP_PARAMS["image_filename"] = IMAGE_FILENAME = loaded_imgs_and_paths[i][1][0]
            EXP_PARAMS["img_res"] = "{0}x{1}".format(loaded_imgs_and_paths[i][0][1].shape[1], loaded_imgs_and_paths[i][0][1].shape[0])  
            EXP_PARAMS["kernel_size"] = "{0}x{1}".format(p.shape[0], p.shape[1])

            occ = loaded_imgs_and_paths[i][0][3][:,:,0]
            gt = loaded_imgs_and_paths[i][0][2][:,:,0]
            
            left = loaded_imgs_and_paths[i][0][0].astype(np.float64)
            right = loaded_imgs_and_paths[i][0][1].astype(np.float64)
            disps=[]
            
            tic = time.time()
                
            for ch in range(0,3):
            
                matcher.set_images(left[:,:,i], right[:,:,i])

                matcher.configure_instance()
                matcher.set_filter(p)


                x,raw_disp_map = matcher.test_pipeline()
                disps.append(raw_disp_map)
            
            toc = time.time()
            
            EXP_PARAMS["runtime"] = toc-tic
            
            disps = np.array(disps)
            disp = (disps[0] + disps[1] +disps[2])/3
            disp = 4*disp
            
            temp_path = u.save_disparity(SAVE_PATH, disp)
            saved_image_names.append(os.path.split(temp_path)[-1])
        
            EXP_PARAMS["image_filename"] = temp_path

            EXP_PARAMS["are_occlusions_errors"] = ARE_OCCLUSIONS_ERRORS = False

            EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
            BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, occ, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

            csv_logger.append_new_sm_results(EXP_PARAMS, selected_keys=csv.get_header_v3())

            EXP_PARAMS["are_occlusions_errors"]  = True
            EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
            BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, gt, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

            csv_logger.append_new_sm_results(EXP_PARAMS, selected_keys=csv.get_header_v3())
            results.append(disp)

            progress_bar.progress_bar(progress_counter, steps_to_be_taken, header= "Experiment on patch sizes in progress: ", progress_bar_steps=40)
            progress_counter+=1
# Out:
# Experiment on patch sizes in progress:  [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>----------] 75.00 % completed: 36 / 48 steps

# %%
SAVE_PATH  = os.path.join(ROOT_PATH, "experiments", "disparities", EXPERIMENT_TITLE)
saved_image_names = []
for result in results:
    temp_path = u.save_disparity(SAVE_PATH, result)
    saved_image_names.append(os.path.split(temp_path)[-1])

# %%
import pandas as pd
experiment_log = pd.read_csv(CSV_FILEPATH)
experiment_log.sort_values(by="bad4", inplace=True) 
experiment_log.head(30)
# Out:
#                                         experiment_id  match  gap  egap  \
# 62  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 66  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 70  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 58  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 54  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 50  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 42  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 34  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 38  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 46  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 30  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 26  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 6   ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 10  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 2   ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 14  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 18  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 22  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     10  -20    -1
# 63  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 67  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 71  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 59  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 55  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 51  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 60  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 48  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 52  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 64  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
# 43  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     20  -20    -1
# 56  ALG_005_EXP_007-PatchMatch-MacLean_et_al-Numba...     30  -20    -1
#
#                                      algo    init_method     dataset  scene  \
# 62  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 66  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 70  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 58  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 54  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 50  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 42  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 34  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 38  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 46  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 30  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 26  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 6   components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 10  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 2   components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 14  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 18  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 22  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 63  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 67  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 71  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 59  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 55  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 51  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 60  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  teddy
# 48  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  teddy
# 52  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  teddy
# 64  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  teddy
# 43  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  cones
# 56  components.matchers.NumbaPatchMatcher  maclean_et_al  middlebury  teddy
#
#                                        image_filename  img_res  ...  \
# 62  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 66  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 70  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 58  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 54  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 50  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 42  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 34  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 38  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 46  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 30  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 26  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 6   ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 10  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 2   ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 14  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 18  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 22  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 63  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 67  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 71  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 59  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 55  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 51  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 60  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 48  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 52  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 64  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 43  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
# 56  ..\..\experiments\disparities\ALG_005_EXP_007-...  450x375  ...
#
#    are_occlusions_errors  abs_error          mse        avg     eucledian  \
# 62                 False  1087906.0   741.763239   7.558787  10332.425465
# 66                 False  1101048.0   749.128524   7.650098  10383.596294
# 70                 False  1117572.0   762.463044   7.764907  10475.602894
# 58                 False  1093116.0   743.430485   7.594986  10344.030936
# 54                 False  1103858.0   739.991384   7.669622  10320.077519
# 50                 False  1123796.0   753.186832   7.808151  10411.684206
# 42                 False  1233222.0   884.429999   8.568445  11282.396554
# 34                 False  1203774.0   853.318233   8.363840  11082.178486
# 38                 False  1218598.0   872.993010   8.466837  11209.210142
# 46                 False  1269956.0   919.669497   8.823673  11504.970752
# 30                 False  1199748.0   843.830357   8.335867  11020.396000
# 26                 False  1213194.0   849.896419   8.429290  11059.936347
# 6                  False  1954896.0  1617.545294  13.582647  15258.008520
# 10                 False  2028230.0  1686.668093  14.092172  15580.609487
# 2                  False  1886550.0  1530.276948  13.107778  14840.708878
