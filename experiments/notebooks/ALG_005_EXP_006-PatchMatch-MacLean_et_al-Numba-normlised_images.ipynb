# %%
###################################################################
# Built-in modules ################################################
###################################################################
import sys
import os

sys.path.append("../../")

import numpy as np
import imp
import cv2
import os
import matplotlib.pyplot as plt
import gc

import math
import time
import glob

###################################################################
# Custom modules ##################################################
###################################################################

from components.matchers.NumbaPatchMatcher import Wrapper as m
from components.utils.SimpleProgressBar import SimpleProgressBar
from components.utils import utils as u
from components.utils import plot_utils as plu
from components.utils.CSVWriter2 import Wrapper as csv
from components.utils.Metrix import Wrapper as me

###################################################################
# Dataset specific modules#########################################
###################################################################

from components.utils import middlebury_utils as mbu

# %%
ROOT_PATH = os.path.join("..", "..")
EXPERIMENT_TITLE = "ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba-normlised_images"

INIT_METHOD = "maclean"
DATASET = "middlebury"

DATASET_FOLDER = os.path.join(ROOT_PATH, "datasets", DATASET)
LOG_FOLDER = os.path.join(ROOT_PATH, "experiments", "logs")
CSV_FILEPATH = os.path.join(LOG_FOLDER, EXPERIMENT_TITLE+".csv")
IMG_RES = "450X375"
PREPROCESSING_METHOD = "None"
KERNEL_SIZE = 1
KERNEL_SPEC = "None"

SCENES = ["teddy", "cones"]
SIZE=""
YEAR= 2003
EXP_PARAMS = dict()

# %% [markdown]
# #  Loading the dataset and visualising the results

# %%
loaded_imgs_and_paths = list(mbu.get_images(DATASET_FOLDER, YEAR, scene) for scene in SCENES)

for im, path in loaded_imgs_and_paths:
    filenames = list(os.path.split(p)[-1] for p in path)
    plu.plot_images(im, filenames)
# Out:
# ['im2.png', 'im6.png', 'disp2.png', 'teddy_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\teddy\im2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\im6.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\teddy\teddy_nonocc.png
# ['im2.png', 'im6.png', 'disp2.png', 'cones_nonocc.png']
# ..\..\datasets\middlebury\middlebury_2003\cones\im2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\im6.png
# ..\..\datasets\middlebury\middlebury_2003\cones\disp2.png
# ..\..\datasets\middlebury\middlebury_2003\cones\cones_nonocc.png

# %% [markdown]
# # Benchmarking and evaluation

# %%
###################################################################
# Initialising hyperparameters and matcher#####################
###################################################################

csv_logger = csv(CSV_FILEPATH, default_header=False)
csv_logger.set_header_function(csv_logger.get_header_v3)
csv_logger.write_csv_header()
csv_logger.set_line_function(csv.format_stereo_matching_results_v2)

MATCH = 30/255
GAP = -20/255
EGAP = -1/255


EXP_PARAMS = {"experiment_id":EXPERIMENT_TITLE, "match": MATCH,"gap":GAP,"egap":EGAP,\
                  "algo":str(m.__module__), "init_method":"default","dataset":DATASET,\
                  "preprocessing_method":"None","kernel_size":1,"kernel_spec":"None"}
# Out:
# Directory '..\..\experiments\logs' already exists.

# %%
###################################################################
# Matching ####################################################
###################################################################

results = []

EXP_PARAMS["init_method"] = "maclean_et_al"

patches = [
           np.ones((5,3)), np.ones((7,3)),
           np.ones((9,3)), np.ones((11,3)),
           np.ones((13,3)), np.ones((15,3))
          ]

matcher = m(MATCH, GAP, EGAP)
progress_bar = SimpleProgressBar.get_instance()

progress_counter = 1
steps_to_be_taken = len(SCENES)*len(patches)*7


SAVE_PATH  = os.path.join(ROOT_PATH, "experiments", "disparities", EXPERIMENT_TITLE)

saved_image_names = []
results = []

# %%
for match_value in range(10,40, 10):
    for p in patches:
        for i, scene in enumerate(SCENES):
            EXP_PARAMS["match"] = MATCH = match_value/255
            matcher = m(MATCH, GAP, EGAP)
            
            EXP_PARAMS["scene"] = scene
            EXP_PARAMS["image_filename"] = IMAGE_FILENAME = loaded_imgs_and_paths[i][1][0]
            EXP_PARAMS["img_res"] = "{0}x{1}".format(loaded_imgs_and_paths[i][0][1].shape[1], loaded_imgs_and_paths[i][0][1].shape[0])  
            EXP_PARAMS["kernel_size"] = "{0}x{1}".format(p.shape[0], p.shape[1])

            occ = loaded_imgs_and_paths[i][0][3]
            gt = loaded_imgs_and_paths[i][0][2]
            
            left = loaded_imgs_and_paths[i][0][0].astype(np.float64)/255
            right = loaded_imgs_and_paths[i][0][1].astype(np.float64)/255
            
            
            
            matcher.set_images(left, right)
            tic = time.time()

            matcher.configure_instance()
            matcher.set_filter(p)

            tic=time.time()

            x,raw_disp_map = matcher.test_pipeline()
            toc = time.time()

            EXP_PARAMS["runtime"] = toc-tic

            disp = raw_disp_map
            disp = 4*disp
            
            temp_path = u.save_disparity(SAVE_PATH, disp)
            saved_image_names.append(os.path.split(temp_path)[-1])
        
            EXP_PARAMS["image_filename"] = temp_path

            EXP_PARAMS["are_occlusions_errors"] = ARE_OCCLUSIONS_ERRORS = False

            EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
            BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, occ, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

            csv_logger.append_new_sm_results(EXP_PARAMS, selected_keys=csv.get_header_v3())

            EXP_PARAMS["are_occlusions_errors"]  = True
            EXP_PARAMS["bad1"], EXP_PARAMS["bad2"], EXP_PARAMS["bad4"], EXP_PARAMS["BAD8"], EXP_PARAMS["abs_error"], EXP_PARAMS["mse"], EXP_PARAMS["avg"], EXP_PARAMS["eucledian"] =\
            BAD1, BAD2, BAD4, BAD8, ABS_ERR, MSE, AVG, EUCLEDIAN = me.evaluate_over_all(disp, gt, gt, occlusions_counted_in_errors = ARE_OCCLUSIONS_ERRORS)

            csv_logger.append_new_sm_results(EXP_PARAMS, selected_keys=csv.get_header_v3())
            results.append(disp)

            progress_bar.progress_bar(progress_counter, steps_to_be_taken, header= "Experiment on patch sizes in progress: ", progress_bar_steps=40)
            progress_counter+=1
# Out:
# Experiment on patch sizes in progress:  [>>>>>>>>>>>>>>>>>-----------------------] 42.86 % completed: 36 / 84 steps

# %%
SAVE_PATH  = os.path.join(ROOT_PATH, "experiments", "disparities", EXPERIMENT_TITLE)
saved_image_names = []
for result in results:
    temp_path = u.save_disparity(SAVE_PATH, result)
    saved_image_names.append(os.path.split(temp_path)[-1])

# %%
import pandas as pd
experiment_log = pd.read_csv(CSV_FILEPATH)
experiment_log.sort_values(by="bad1", inplace=True) 
experiment_log.head(30)
# Out:
#                                         experiment_id     match       gap  \
# 34  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 38  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 30  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 42  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 46  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 26  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 58  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 62  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 54  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 66  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 70  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 50  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 10  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 14  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 6   ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 18  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 2   ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 22  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.039216 -0.078431
# 35  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 39  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 31  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 43  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 47  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 27  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.078431 -0.078431
# 59  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 63  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 55  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 67  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 71  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
# 51  ALG_005_EXP_006-PatchMatch-MacLean_et_al-Numba...  0.117647 -0.078431
#
#         egap                                   algo    init_method  \
# 34 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 38 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 30 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 42 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 46 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 26 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 58 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 62 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 54 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 66 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 70 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 50 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 10 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 14 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 6  -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 18 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 2  -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 22 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 35 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 39 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 31 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 43 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 47 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 27 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 59 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 63 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 55 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 67 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 71 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
# 51 -0.003922  components.matchers.NumbaPatchMatcher  maclean_et_al
#
#        dataset  scene                                     image_filename  \
# 34  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 38  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 30  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 42  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 46  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 26  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 58  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 62  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 54  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 66  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 70  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 50  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 10  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 14  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 6   middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 18  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 2   middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 22  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 35  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 39  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 31  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 43  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 47  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 27  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 59  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 63  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 55  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 67  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 71  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
# 51  middlebury  cones  ..\..\experiments\disparities\ALG_005_EXP_006-...
#
#     img_res  ... are_occlusions_errors  abs_error          mse        avg  \
# 34  450x375  ...                 False  1042316.0   758.250712   7.242027
# 38  450x375  ...                 False  1056206.0   773.412504   7.338535
# 30  450x375  ...                 False  1036780.0   748.462849   7.203563
# 42  450x375  ...                 False  1072864.0   782.379278   7.454275
# 46  450x375  ...                 False  1097128.0   802.445868   7.622862
# 26  450x375  ...                 False  1044794.0   748.635549   7.259244
# 58  450x375  ...                 False  1000762.0   684.353404   6.953309
# 62  450x375  ...                 False  1009080.0   687.612690   7.011103
# 54  450x375  ...                 False   997024.0   678.332365   6.927338
# 66  450x375  ...                 False  1019200.0   692.533997   7.081417
# 70  450x375  ...                 False  1035144.0   700.662340   7.192196
# 50  450x375  ...                 False  1005782.0   683.860484   6.988188
# 10  450x375  ...                 False  1753134.0  1469.658519  12.180801
# 14  450x375  ...                 False  1824742.0  1537.236024  12.678335
# 6   450x375  ...                 False  1643586.0  1365.083890  11.419660
# 18  450x375  ...                 False  1908460.0  1609.337521  13.260009
# 2   450x375  ...                 False  1596104.0  1312.837430  11.089754
# 22  450x375  ...                 False  1998692.0  1688.519045  13.886942
# 35  450x375  ...                  True  3364494.0  2975.217467  20.600498
# 39  450x375  ...                  True  3377196.0  2987.921382  20.678272
